# %% [markdown]
# **Unemplyment Data**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
unemployment_df = pd.read_excel("unemployment_data.xlsx" , sheet_name=1)

# %%
unemployment_df.head()
# Out:
#      Indikator    Ausprägung  Jahr                          Raumbezug  \
# 0  Arbeitslose  bis 24 Jahre  2024                      Stadt München
# 1  Arbeitslose  bis 24 Jahre  2024                01 Altstadt - Lehel
# 2  Arbeitslose  bis 24 Jahre  2024  02 Ludwigsvorstadt - Isarvorstadt
# 3  Arbeitslose  bis 24 Jahre  2024                     03 Maxvorstadt
# 4  Arbeitslose  bis 24 Jahre  2024                04 Schwabing - West
#
#   Indikatorwert  Basiswert 1  Basiswert 2            Name Basiswert 1  \
# 0           6,6       2900.0      43723.3  Arbeitslose (bis 24 Jahre)
# 1           4,3         19.8        457.8  Arbeitslose (bis 24 Jahre)
# 2           4,9         67.8       1374.3  Arbeitslose (bis 24 Jahre)
# 3           4,7         62.3       1311.8  Arbeitslose (bis 24 Jahre)
# 4           5,1         74.3       1449.5  Arbeitslose (bis 24 Jahre)
#
#           Name Basiswert 2
# 0  Arbeitslose (insgesamt)
# 1  Arbeitslose (insgesamt)
# 2  Arbeitslose (insgesamt)
# 3  Arbeitslose (insgesamt)
# 4  Arbeitslose (insgesamt)

# %%
unique_pairs = unemployment_df[['Indikator', 'Ausprägung']].drop_duplicates()
print(unique_pairs)
# Out:
#                                                Indikator          Ausprägung
# 0                                            Arbeitslose        bis 24 Jahre
# 650                                          Arbeitslose             deutsch
# 1300                                         Arbeitslose            Langzeit
# 1950                                         Arbeitslose            männlich
# 2600                                         Arbeitslose        nichtdeutsch
# 3250                                         Arbeitslose            weiblich
# 3900                                         Arbeitslose  55 Jahre und älter
# 4550                                Arbeitslose - Anteil             deutsch
# 5200                                Arbeitslose - Anteil           insgesamt
# 5850                                Arbeitslose - Anteil            männlich
# 6500                                Arbeitslose - Anteil        nichtdeutsch
# 7150                                Arbeitslose - Anteil            weiblich
# 7800                                       Erwerbsfähige             deutsch
# 8450                                       Erwerbsfähige           insgesamt
# 9100                                       Erwerbsfähige            männlich
# 9750                                       Erwerbsfähige        nichtdeutsch
# 10400                                      Erwerbsfähige            weiblich
# 11050                       (Regel-)Leistungsberechtigte        erwerbsfähig
# 11544                       (Regel-)Leistungsberechtigte  nicht erwerbsfähig
# 12038        (Regel-)Leistungsberechtigte - erwerbsfähig             deutsch
# 12532        (Regel-)Leistungsberechtigte - erwerbsfähig            männlich
# 13026        (Regel-)Leistungsberechtigte - erwerbsfähig        nichtdeutsch
# 13520        (Regel-)Leistungsberechtigte - erwerbsfähig            weiblich
# 14014  (Regel-)Leistungsberechtigte - erwerbsfähig - ...             deutsch
# 14508  (Regel-)Leistungsberechtigte - erwerbsfähig - ...           insgesamt
# 15002  (Regel-)Leistungsberechtigte - erwerbsfähig - ...            männlich
# 15496  (Regel-)Leistungsberechtigte - erwerbsfähig - ...        nichtdeutsch
# 15990  (Regel-)Leistungsberechtigte - erwerbsfähig - ...            weiblich
# 16484  (Regel-)Leistungsberechtigte - nicht erwerbsfä...           insgesamt
# 16978          Sozialversicherungspflichtig Beschäftigte             deutsch
# 17628          Sozialversicherungspflichtig Beschäftigte            männlich
# 18278          Sozialversicherungspflichtig Beschäftigte        nichtdeutsch
# 18928          Sozialversicherungspflichtig Beschäftigte            weiblich
# 19578          Sozialversicherungspflichtig Beschäftigte  25 Jahre und älter
# 20228  Sozialversicherungspflichtig Beschäftigte - An...             deutsch
# 20878  Sozialversicherungspflichtig Beschäftigte - An...           insgesamt
# 21528  Sozialversicherungspflichtig Beschäftigte - An...            männlich
# 22178  Sozialversicherungspflichtig Beschäftigte - An...        nichtdeutsch
# 22828  Sozialversicherungspflichtig Beschäftigte - An...            weiblich

# %% [markdown]
# **Unemployed Total**

# %%
df_unemployed_total = unemployment_df[(unemployment_df['Indikator'] == 'Arbeitslose - Anteil') & (unemployment_df['Ausprägung'] == 'insgesamt')]

# %%
df_unemployed_total.head()
# Out:
#                  Indikator Ausprägung  Jahr  \
# 5200  Arbeitslose - Anteil  insgesamt  2024
# 5201  Arbeitslose - Anteil  insgesamt  2024
# 5202  Arbeitslose - Anteil  insgesamt  2024
# 5203  Arbeitslose - Anteil  insgesamt  2024
# 5204  Arbeitslose - Anteil  insgesamt  2024
#
#                               Raumbezug Indikatorwert  Basiswert 1  \
# 5200                      Stadt München           3,9      43723.3
# 5201                01 Altstadt - Lehel             3        457.8
# 5202  02 Ludwigsvorstadt - Isarvorstadt           3,5       1374.3
# 5203                     03 Maxvorstadt           3,2       1311.8
# 5204                04 Schwabing - West           2,9       1449.5
#
#       Basiswert 2         Name Basiswert 1  \
# 5200    1117076.3  Arbeitslose (insgesamt)
# 5201      15370.0  Arbeitslose (insgesamt)
# 5202      39057.0  Arbeitslose (insgesamt)
# 5203      41348.3  Arbeitslose (insgesamt)
# 5204      49670.8  Arbeitslose (insgesamt)
#
#                                        Name Basiswert 2
# 5200  Hauptwohnsitzbevölkerung (15 bis 64 Jahre) (in...
# 5201  Hauptwohnsitzbevölkerung (15 bis 64 Jahre) (in...
# 5202  Hauptwohnsitzbevölkerung (15 bis 64 Jahre) (in...
# 5203  Hauptwohnsitzbevölkerung (15 bis 64 Jahre) (in...
# 5204  Hauptwohnsitzbevölkerung (15 bis 64 Jahre) (in...

# %%
df_unemployed_total = df_unemployed_total.drop(columns=['Indikator', 'Basiswert 1','Basiswert 2', 'Name Basiswert 1','Name Basiswert 2','Ausprägung'])
df_unemployed_total.rename(columns={'Indikatorwert': 'Value', "Raumbezug": "Location" , "Jahr": "Year"}, inplace=True)
df_unemployed_total = df_unemployed_total.reset_index(drop=True)
df_unemployed_total['Year'] = df_unemployed_total['Year'].astype(int)

# %%
df_unemployed_total.head()
# Out:
#    Year                           Location Value
# 0  2024                      Stadt München   3,9
# 1  2024                01 Altstadt - Lehel     3
# 2  2024  02 Ludwigsvorstadt - Isarvorstadt   3,5
# 3  2024                     03 Maxvorstadt   3,2
# 4  2024                04 Schwabing - West   2,9

# %%
# Work on a copy
df = df_unemployed_total.copy()

# Ensure correct column names
df.columns = [c.strip() for c in df.columns]

# Convert columns to numeric
df["Overall Population"] = pd.to_numeric(df["Value"], errors="coerce")
df["Year"] = pd.to_numeric(df["Year"], errors="coerce")

# Create pivot: rows = Year, columns = Location, values = Overall Population
pivot_df = df.pivot(index="Year", columns="Location", values="Overall Population")

# Choose locations to exclude from the legend (optional)
exclude = ["Stadt München"]  # example: remove the overall city line from legend

# Plot
plt.figure(figsize=(16, 8))  # Adjust figure size

for col in pivot_df.columns:
    if col not in exclude:
        plt.plot(
            pivot_df.index,
            pivot_df[col],
            label=col,
            linewidth=2,       # line thickness
            linestyle='-',     # line style
            marker='o',        # marker at each data point
            alpha=0.8          # transparency
        )

plt.ylabel("Population", fontsize=14)
plt.xlabel("Year", fontsize=14)
plt.title("Population Change Over Time per District in Munich", fontsize=16)

# Customize legend
plt.legend(
    title="Location",
    bbox_to_anchor=(1.05, 1),  # move outside to the right
    loc="upper left",
    fontsize=10,
    title_fontsize=12
)

plt.tight_layout()  # adjust layout to fit everything
plt.show()

# %%
pivot_df.head()
pivot_df.isna().sum()
# Out:
# Location
# 01 Altstadt - Lehel                                                  23
# 02 Ludwigsvorstadt - Isarvorstadt                                    23
# 03 Maxvorstadt                                                       23
# 04 Schwabing - West                                                  23
# 05 Au - Haidhausen                                                   23
# 06 Sendling                                                          22
# 07 Sendling - Westpark                                               23
# 08 Schwanthalerhöhe                                                  22
# 09 Neuhausen - Nymphenburg                                           22
# 10 Moosach                                                           23
# 11 Milbertshofen - Am Hart                                           21
# 12 Schwabing - Freimann                                              24
# 13 Bogenhausen                                                       21
# 14 Berg am Laim                                                      23
# 15 Trudering - Riem                                                  25
# 16 Ramersdorf - Perlach                                              21
# 17 Obergiesing - Fasangarten                                         21
# 18 Untergiesing - Harlaching                                         25
# 19 Thalkirchen - Obersendling - Forstenried - Fürstenried - Solln    22
# 20 Hadern                                                            22
# 21 Pasing - Obermenzing                                              24
# 22 Aubing - Lochhausen - Langwied                                    23
# 23 Allach - Untermenzing                                             21
# 24 Feldmoching - Hasenbergl                                          24
# 25 Laim                                                              23
# Stadt München                                                        23
# dtype: int64

# %%
df_unemployed_total['District'] = df_unemployed_total['Location'].str.extract(r'^(\d{2})')  # Extract the first two digits

# Handle rows like 'Stadt München' (no digits)
df_unemployed_total['District'] = df_unemployed_total['District'].fillna('00')

# Remove the leading number and dash from Location text
df_unemployed_total['Location'] = df_unemployed_total['Location'].str.replace(r'^\d{2}\s*-\s*', '', regex=True)
df_unemployed_total['Location'] = df_unemployed_total['Location'].str.replace(r'^\d{2}\s*', '', regex=True)
# (Optional) Clean up whitespace
df_unemployed_total['Location'] = df_unemployed_total['Location'].str.strip()

print(df_unemployed_total.head(10))
# Out:
#    Year                        Location Value District
# 0  2024                   Stadt München   3,9       00
# 1  2024                Altstadt - Lehel     3       01
# 2  2024  Ludwigsvorstadt - Isarvorstadt   3,5       02
# 3  2024                     Maxvorstadt   3,2       03
# 4  2024                Schwabing - West   2,9       04
# 5  2024                 Au - Haidhausen   3,6       05
# 6  2024                        Sendling   4,1       06
# 7  2024             Sendling - Westpark   3,9       07
# 8  2024                Schwanthalerhöhe   4,4       08
# 9  2024         Neuhausen - Nymphenburg   3,3       09

# %%
df_unemployed_total.to_csv("cleaned_districts_unemployment.csv", index=False, encoding='utf-8')

# %%
df_unemployed_total[df_unemployed_total["District"] == "24"]
# Out:
#      Year                  Location Value District
# 24   2024  Feldmoching - Hasenbergl   4,5       24
# 50   2023  Feldmoching - Hasenbergl     4       24
# 76   2022  Feldmoching - Hasenbergl   3,9       24
# 102  2021  Feldmoching - Hasenbergl   4,5       24
# 128  2020  Feldmoching - Hasenbergl   4,5       24
# 154  2019  Feldmoching - Hasenbergl   3,3       24
# 180  2018  Feldmoching - Hasenbergl   3,6       24
# 206  2017  Feldmoching - Hasenbergl   4,1       24
# 232  2016  Feldmoching - Hasenbergl   4,5       24
# 258  2015  Feldmoching - Hasenbergl   4,7       24
# 284  2014  Feldmoching - Hasenbergl   4,8       24
# 310  2013  Feldmoching - Hasenbergl   4,9       24
# 336  2012  Feldmoching - Hasenbergl   4,5       24
# 362  2011  Feldmoching - Hasenbergl   4,8       24
# 388  2010  Feldmoching - Hasenbergl   5,1       24
# 414  2009  Feldmoching - Hasenbergl   5,3       24
# 440  2008  Feldmoching - Hasenbergl   4,9       24
# 466  2007  Feldmoching - Hasenbergl   5,9       24
# 492  2006  Feldmoching - Hasenbergl   7,5       24
# 518  2005  Feldmoching - Hasenbergl   8,8       24
# 544  2004  Feldmoching - Hasenbergl   5,7       24
# 570  2003  Feldmoching - Hasenbergl   5,9       24
# 596  2002  Feldmoching - Hasenbergl   4,9       24
# 622  2001  Feldmoching - Hasenbergl   3,8       24
# 648  2000  Feldmoching - Hasenbergl   4,1       24
